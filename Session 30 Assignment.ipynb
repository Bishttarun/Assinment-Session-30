# %% [markdown]
# # Problem Statement¶
# In this assignment students have to compress racoon grey scale image into 5 clusters. In the end, visualize both raw and compressed image and look for quality difference. The raw image is available in spicy.misc package with the name face.
# Hint:
# import numpy as np from sklearn import cluster, datasets from scipy import misc

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from sklearn import cluster, datasets
import scipy.misc
face = scipy.misc.face(gray=False)

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
plt.figure(figsize=(8,8), dpi=100)
plt.imshow(face)

# %%
face_reshape = (face / 255).reshape(-1,3)

# %%
face_reshape.shape
# Out:
# (786432, 3)

# %%
from sklearn.cluster import KMeans
k_colors = KMeans(n_clusters=5).fit(face_reshape)
y_pred=k_colors.predict(face_reshape)

# %%
k_colors.cluster_centers_.shape
# Out:
# (5, 3)

# %%
k_colors.labels_.shape
# Out:
# (786432,)

# %%
newimg=k_colors.cluster_centers_[k_colors.labels_]

# %%
newimg.shape
# Out:
# (786432, 3)

# %%
newimg=np.reshape(newimg, (face.shape))

# %%
newimg.shape
# Out:
# (768, 1024, 3)

# %%
fig = plt.figure(figsize=(20,20))
ax=fig.add_subplot(1,2,1,xticks=[],yticks=[],title='Original Image')
ax.imshow(face)
ax=fig.add_subplot(1,2,2,xticks=[],yticks=[],title='Color Compressed Image using K-Means with 5 clusters')
ax.imshow(newimg)
plt.show()
